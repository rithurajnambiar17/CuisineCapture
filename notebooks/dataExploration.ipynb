# %%
import pandas as pd

# %%
data = pd.read_csv('../data/train/_annotations.csv')
data
# Out:
#                                                 filename  width  height  \
# 0      istockphoto-1301781280-612x612_jpg.rf.0012adef...    612     408
# 1      istockphoto-1301781280-612x612_jpg.rf.0012adef...    612     408
# 2      istockphoto-1143557005-612x612_jpg.rf.001c645e...    612     563
# 3      istockphoto-519684644-612x612_jpg.rf.002c31336...    408     612
# 4      istockphoto-173618523-612x612_jpg.rf.0031b32b5...    612     407
# ...                                                  ...    ...     ...
# 22402  istockphoto-183216138-612x612_jpg.rf.df6c3a40c...    612     408
# 22403  istockphoto-183216138-612x612_jpg.rf.df6c3a40c...    612     408
# 22404  istockphoto-183216138-612x612_jpg.rf.df6c3a40c...    612     408
# 22405  istockphoto-1147588437-612x612_jpg.rf.df45fb9a...    612     561
# 22406  istockphoto-172231757-612x612_jpg.rf.df8a39918...    612     541
#
#        class  xmin  ymin  xmax  ymax
# 0          8   116     0   474   395
# ...

# %%
len(data['class'].unique())
# Out:
# 13
